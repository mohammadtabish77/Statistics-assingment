# %% [markdown]
# **Q1. What are the three measures of central tendency?**
#
# The three measures of central tendency are:
# - Mean
# - Median
# - Mode
#
# **Q2. What is the difference between the mean, median, and mode? How are they used to measure the central tendency of a dataset?**
#
# - **Mean:** The mean is the average of all values in a dataset. It is calculated by summing all values and dividing by the number of values. The mean is sensitive to outliers.
#
# - **Median:** The median is the middle value when the data is arranged in ascending order. If there is an even number of data points, the median is the average of the two middle values. The median is less affected by outliers than the mean.
#
# - **Mode:** The mode is the value that appears most frequently in the dataset. A dataset may have one mode (unimodal), two modes (bimodal), or more (multimodal). The mode can be used for both numerical and categorical data.
#
# These measures provide different perspectives on the central tendency of a dataset, helping to understand where most values are concentrated.
#
# **Q3. Measure the three measures of central tendency for the given height data:**
#
# Height data: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
#
# - **Mean:** Sum all values and divide by the number of values.
#   \[
#   \text{Mean} = \frac{178 + 177 + 176 + \ldots + 176.5}{16} = 177.8125
#   \]
#
# - **Median:** Arrange data in ascending order and find the middle value.
#   Sorted data: [172.5, 175, 175, 176, 176, 176.2, 177, 177, 177, 178, 178, 178, 178.2, 178.9, 179, 180]
#   Median = 177 (the 8th value in sorted list)
#
# - **Mode:** The mode is the most frequent value in the dataset.
#   Mode = 178 (appears 4 times)
#
# **Q4. Find the standard deviation for the given data:**
#
# Data: [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
#
# Standard deviation measures the amount of variation or dispersion in a set of values. It is calculated as the square root of the variance.
#
# - First, calculate the mean (already found in Q3):
#   Mean = 177.8125
#
# - Calculate the variance:
#   \[
#   \text{Variance} = \frac{\sum (X_i - \text{Mean})^2}{n-1}
#   \]
#   Calculate squared differences for each value, sum them, and divide by \( n-1 \).
#
# - Finally, take the square root to find the standard deviation.
#
# **Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe the spread of a dataset? Provide an example.**
#
# Measures of dispersion quantify how spread out the values in a dataset are from the central tendency measures (mean, median, mode).
#
# - **Range:** The difference between the maximum and minimum values in the dataset. It provides a simple measure of spread.
#
# - **Variance and Standard Deviation:** Variance measures the average squared difference of each value from the mean, while standard deviation is the square root of variance. They provide a more precise measure of dispersion, accounting for all data points.
#
# Example: Consider two datasets of test scores:
# Dataset A: [75, 80, 85, 90, 95]
# Dataset B: [60, 70, 85, 90, 100]
#
# - Range:
#   - Dataset A: Range = 95 - 75 = 20
#   - Dataset B: Range = 100 - 60 = 40
#
# - Variance and Standard Deviation:
#   - Calculate for each dataset to compare the spread of scores.
#
# **Q6. What is a Venn diagram?**
#
# A Venn diagram is a visual representation used to show the relationships between sets or groups of objects. It consists of overlapping circles or other shapes, where each circle represents a set and the overlap represents common elements between sets.
#
# **Q7. For the two given sets A = {2, 3, 4, 5, 6, 7} & B = {0, 2, 6, 8, 10}, find:**
#
# (i) **A ∩ B** (intersection - elements common to both sets):
#    \[
#    A \cap B = \{2, 6\}
#    \]
#
# (ii) **A ⋃ B** (union - all elements from both sets, without duplicates):
#    \[
#    A \cup B = \{0, 2, 3, 4, 5, 6, 7, 8, 10\}
#    \]
#
# **Q8. What do you understand about skewness in data?**
#
# Skewness in data refers to the asymmetry or lack of symmetry in the distribution of data points around the mean. It indicates whether the data distribution is skewed to the left (negative skewness), skewed to the right (positive skewness), or symmetric (zero skewness).
#
# **Q9. If a data is right skewed then what will be the position of median with respect to mean?**
#
# If data is right-skewed (positive skewness), it means that there are more values concentrated on the left side of the distribution, with a long tail extending to the right. In this case:
# - The mean will be greater than the median because the presence of outliers or higher values on the right side of the distribution pulls the mean towards higher values.
#
# **Q10. Explain the difference between covariance and correlation. How are these measures used in statistical analysis?**
#
# - **Covariance:** Covariance measures the degree to which two variables change together. It indicates the direction of the linear relationship between variables (positive, negative, or no relationship). However, it does not indicate the strength of the relationship.
#
# - **Correlation:** Correlation is a standardized measure that quantifies the strength and direction of the linear relationship between two variables. It ranges from -1 to +1, where -1 indicates a perfect negative linear relationship, +1 indicates a perfect positive linear relationship, and 0 indicates no linear relationship.
#
# In statistical analysis, covariance and correlation are used to understand relationships between variables, assess the strength and direction of associations, and make predictions based on observed patterns.
#
# **Q11. What is the formula for calculating the sample mean? Provide an example calculation for a dataset.**
#
# The sample mean (\( \bar{X} \)) is calculated as the sum of all values divided by the number of values (n):
#
# \[ \bar{X} = \frac{\sum X_i}{n} \]
#
# Example calculation:
# Dataset: [10, 15, 12, 18, 20]
#
# \[ \bar{X} = \frac{10 + 15 + 12 + 18 + 20}{5} = \frac{75}{5} = 15 \]
#
# So, the sample mean for this dataset is 15.
#
# **Q12. For a normal distribution data what is the relationship between its measure of central tendency?**
#
# For a normal distribution:
# - The mean, median, and mode are all equal.
# - This symmetry is a characteristic feature of the normal distribution, where the data is evenly distributed around the mean.
#
# **Q13. How is covariance different from correlation?**
#
# - **Covariance:** Measures the direction of the linear relationship between two variables. It is affected by the scale of the variables and can range from negative infinity to positive infinity.
#
# - **Correlation:** Standardized measure that quantifies both the strength and direction of the linear relationship between two variables. It ranges from -1 to +1, where -1 indicates a perfect negative linear relationship, +1 indicates a perfect positive linear relationship, and 0 indicates no linear relationship.
#
# **Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.**
#
# Outliers are data points that are significantly different from the majority of the data. They can skew measures of central tendency and dispersion:
#
# - **Central Tendency:** Outliers can pull the mean away from the typical center of the data, making it less representative of the dataset compared to the median or mode.
#
# - **Dispersion:** Outliers can increase the range and standard deviation of the dataset, indicating higher variability than actually present in the main body of data.
#
# Example:
# Consider a dataset of incomes for a small group:
# [30, 32, 31, 33, 32, 30, 31, 32, 500]
#
# - **Mean without outlier:** (30 + 32 + 31 + 33 + 32 + 30 + 31 + 32) / 8 = 31.125
# - **Mean with outlier:** (30 + 32 + 31 + 33 + 32 + 30 + 31 + 32 + 500) / 9 = 79.56
#
# The mean is greatly affected by the outlier (500), whereas the median and mode remain relatively unchanged.
